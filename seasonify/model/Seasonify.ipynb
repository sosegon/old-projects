# %% [markdown]
# # Seasonify
#
# Convolutional Neural Network to predict the seasonal color of a person.
#
# According to [Color Analysis](https://en.wikipedia.org/wiki/Color_analysis_%28art%29) there are four main seasonal colors (Autumn, Spring, Summer, Winter). The categorization of a person within these classes is aimed to provide helpful information about the colors for clothes and makeup that best fits a person's skin complexion, eye color, and hair color.

# %% [markdown]
# ## 1. Load data
#
# There are many faces databases out there. In this particular project I will be using the [Color Feret database](https://www.nist.gov/itl/iad/image-group/color-feret-database)
#
# The images were collected in a semi-controlled environment.The FERET database was collected in 15 sessions between August 1993 and July 1996. The database contains 1564 sets of images for a total of 14,126 images that includes 1199 individuals.
#
# The database contains images of the face in different angles with respect to the camera. Here, The database has been previously purged to only use the images where the angle to the camera is 0, +15, and -15.
#
# Moreover, the seleted images have been cropped to show the face as much as possible within the frame. This removed unneeded information like background and clothes. After that, the pictures were resized to 128 x 128 pixels.

# %%
import glob
import numpy as np

def load_data_color_feret():
    
    autumn_path = "./colorferet_smaller/autumn"
    spring_path = "./colorferet_smaller/spring"
    summer_path = "./colorferet_smaller/summer"
    winter_path = "./colorferet_smaller/winter"

    X, y = [], []

    # autumn = 0
    # spring = 1
    # summer = 2
    # winter = 3
    for i, season_path in enumerate([autumn_path, spring_path, summer_path, winter_path]):
        for fname in glob.glob(season_path + "/*"): # regex for front images
            X.append(fname)
            y.append(i)
        
    return np.array(X), np.array(y)

# This database contains faces of brazilian college students
# The number of faces is smaller and there is no enough
# diversity
def load_data_fei():
    
    autumn_path = "./fei/autumn"
    spring_path = "./fei/spring"
    summer_path = "./fei/summer"
    winter_path = "./fei/winter"

    X, y = [], []

    # autumn = 0
    # spring = 1
    # summer = 2
    # winter = 3
    for i, season_path in enumerate([autumn_path, spring_path, summer_path, winter_path]):
        for fname in glob.glob(season_path + "/*"): # regex for front images
            X.append(fname)
            y.append(i)
        
    return np.array(X), np.array(y)

# This database contains faces of people from the 
# University of Georgia.
# The number of faces is smaller and there is no enough
# diversity
def load_data_georgia():
    
    autumn_path = "./georgia/autumn"
    spring_path = "./georgia/spring"
    summer_path = "./georgia/summer"
    winter_path = "./georgia/winter"

    X, y = [], []

    # autumn = 0
    # spring = 1
    # summer = 2
    # winter = 3
    for i, season_path in enumerate([autumn_path, spring_path, summer_path, winter_path]):
        for fname in glob.glob(season_path + "/*"): # regex for front images
            X.append(fname)
            y.append(i)
        
    return np.array(X), np.array(y)

def load_data(source):
    
    if source == "color_feret":
        return load_data_color_feret()
    elif source == "fei":
        return load_data_fei()
    elif source == "georgia":
        return load_data_georgia()

X_all, y_all = load_data("color_feret")

assert len(X_all) == len(y_all)
print("Number of records in dataset: {:d}".format(len(X_all)))
# Out:
# Number of records in dataset: 3383

# %% [markdown]
# ### 1.1 Visualize samples
#
# The classification of the images within one of the four categories (Autumn, Spring, Summer and Winter) was done manually. There are several ways to determine the seasonal color of a person. In this project, I used the method proposed [here](http://www.thechicfashionista.com/seasonal-color-analysis-2.html).

# %%
import matplotlib.pyplot as plt
from random import randrange
import cv2
# %matplotlib inline

def get_random_images(X_data, y_data, number, clazz):
    samples = []
    
    while len(samples) < number:
        index = randrange(len(X_data))
        
        y = y_data[index]
        
        if y == clazz:
            samples.append(X_data[index])
            
    return np.array(samples)
        
def plot_images(images, titles, colors, interpolation="nearest"):
    assert len(images) == len(titles)
    n = len(images)
    
    f, ax = plt.subplots(1, n, figsize=(12, 12))
    
    for i, a in enumerate(ax):
        a.axis("off")
        a.imshow(cv2.cvtColor(images[i], cv2.COLOR_BGR2RGB), interpolation=interpolation)
        a.set_title(titles[i], fontsize=10, color=colors[i])

def plot_random_images(number):
    
    for i, clazz in enumerate(["Autumn", "Spring", "Summer", "Winter"]):
        paths = get_random_images(X_all, y_all, number, i)
        images = []
        titles = []
        colors = []
        for path in paths:
            images.append(cv2.imread(path))
            titles.append(clazz)
            colors.append("black")
        
        plot_images(images, titles, colors)
    
plot_random_images(10)

# %% [markdown]
# ## 2. Analyze data
# ### 2.1. Histogram of classes

# %%
def histogram_of_classes():
    plt.hist(y_all, 4, (0, 4))
    plt.title("Classes histogram")
    plt.show()
    
    print("Number of elements in class Autumn: {:d}".format(len(y_all[y_all == 0])))
    print("Number of elements in class Spring: {:d}".format(len(y_all[y_all == 1])))
    print("Number of elements in class Summer: {:d}".format(len(y_all[y_all == 2])))
    print("number of elements in class Winter: {:d}".format(len(y_all[y_all == 3])))
    
    x_index = randrange(len(X_all))
    x_path = X_all[x_index]
    
    x_sample = cv2.imread(x_path)
    
    print("Shape of samples: {}".format(x_sample.shape))
    
histogram_of_classes()
# Out:
# Number of elements in class Autumn: 956
# Number of elements in class Spring: 583
# Number of elements in class Summer: 1164
# number of elements in class Winter: 680
# Shape of samples: (128, 128, 3)

# %% [markdown]
# ### 2.2. Color spaces
#
# There are many color spaces that can be used. However, one of the favorite color spaces for skin detection is [YCbCr](https://en.wikipedia.org/wiki/YCbCr) which will be used here.

# %%
def plot_channels(images, titles, color_space, interpolation="nearest"):
    fig, ax = plt.subplots(len(images), 4, figsize=(12, 12))
    fig.tight_layout()
    for i, col in enumerate(ax):
        for j, row in enumerate(col):
            ax[i][j].axis("off")
            if j == 0:
                ax[i][j].imshow(cv2.cvtColor(images[i], cv2.COLOR_BGR2RGB), interpolation=interpolation)
                ax[i][j].set_title(titles[i])
            elif j == 1:
                ax[i][j].imshow(images[i][:,:,0], cmap="gray", interpolation=interpolation)
                ax[i][j].set_title(color_space + " channel 0")
            elif j == 2:
                ax[i][j].imshow(images[i][:,:,1], cmap="gray", interpolation=interpolation)
                ax[i][j].set_title(color_space + " channel 1")
            elif j == 3:
                ax[i][j].imshow(images[i][:,:,2], cmap="gray", interpolation=interpolation)
                ax[i][j].set_title(color_space + " channel 2")
        
    plt.subplots_adjust(left=0., right=.5, top=.375, bottom=.1)

def visualize_color_space(number, color_space):
    for i, clazz in enumerate(["Autumn", "Spring", "Summer", "Winter"]):
        paths = get_random_images(X_all, y_all, number, i)
        
        images = []
        titles = []
        for path in paths:
            image = cv2.imread(path)
            titles.append(clazz)
            if color_space == "YUV":
                images.append(cv2.cvtColor(image, cv2.COLOR_BGR2YUV))
            elif color_space == "YCR_CB":
                images.append(cv2.cvtColor(image, cv2.COLOR_BGR2YCR_CB))
        
        plot_channels(images, titles, color_space)
        
visualize_color_space(2, "YCR_CB")

# %% [markdown]
# ## 3. Augment Data
#
# The objective is to reduce overfitting and make the model generalize better. There are three modifications that can be applied to the images:
#   * Blur
#   * Translatinon
#   * Rotation
#
# The mentioned modifications will be applied over the images randomly.

# %%
def blur_image(x):
    x_blur = cv2.GaussianBlur(x, (3, 3), 0)
   
    return x_blur

def translate_image(x):
    h, w, d = x.shape
    
    delta_y = randrange(int(h * 0.05), int(h * 0.1)) # 5 - 10% of height
    delta_x = randrange(int(w * 0.05), int(w * 0.1)) # 5 - 10% of width
    
    factor = 1 if randrange(0, 2) == 0 else -1
    
    delta_y *= factor
    delta_x *= factor
    
    M = np.float32([[1, 0, delta_x], [0, 1, delta_y]])
    x_translated = cv2.warpAffine(x, M, (w, h))
    
    return x_translated

def rotate_image(x):
    h, w, d = x.shape

    delta = randrange(1, 16) # between 0 - 15 degrees

    M = cv2.getRotationMatrix2D((w/2,h/2), delta, 1)
    x_rotated = cv2.warpAffine(x, M, (w, h))
    
    return x_rotated

def augment_image(x, random_limit):
    
    augmented = np.copy(x)
    limit = random_limit

    factor = randrange(0, limit)
    if factor == 0:
        augmented = translate_image(augmented)
        
    factor = randrange(0, limit)
    if factor == 0:
        augmented = rotate_image(augmented)
        
    factor = randrange(0, limit)
    if factor == 0:
        augmented = blur_image(augmented)
        
    return augmented
    
def plot_augmentations(images, titles, interpolation="nearest"):
    fig, ax = plt.subplots(len(images), 7, figsize=(12, 12))
    fig.tight_layout()
    for i, col in enumerate(ax):
        for j, row in enumerate(col):
            ax[i][j].axis("off")
            if j == 0:
                ax[i][j].imshow(cv2.cvtColor(images[i], cv2.COLOR_BGR2RGB), interpolation=interpolation)
                ax[i][j].set_title(titles[i])
            elif j == 1:
                ax[i][j].imshow(cv2.cvtColor(blur_image(images[i]), cv2.COLOR_BGR2RGB), interpolation=interpolation)
                ax[i][j].set_title("Blur")
            elif j == 2:
                ax[i][j].imshow(cv2.cvtColor(translate_image(images[i]), cv2.COLOR_BGR2RGB), interpolation=interpolation)
                ax[i][j].set_title("Translate")
            elif j == 3:
                ax[i][j].imshow(cv2.cvtColor(rotate_image(images[i]), cv2.COLOR_BGR2RGB), interpolation=interpolation)
                ax[i][j].set_title("Rotation")
            elif j == 4:
                ax[i][j].imshow(cv2.cvtColor(augment_image(images[i], 2), cv2.COLOR_BGR2RGB), interpolation=interpolation)
                ax[i][j].set_title("Augmented")
                
    plt.subplots_adjust(left=0., right=.5, top=.25, bottom=.1)


def visualize_augmentations(number):
    
    for i, clazz in enumerate(["Autumn", "Spring", "Summer", "Winter"]):
        paths = get_random_images(X_all, y_all, number, i)
        
        images = []
        titles = []
        for path in paths:
            image = cv2.imread(path)
            images.append(image)
            titles.append(clazz)
        
        plot_augmentations(images, titles)

visualize_augmentations(2)

# %% [markdown]
# ## 4. Define Model
#
# The model is a neural network with 4 convolutions and 4 fully connected layers. Relu activations are used before each layer.

# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten, Lambda
from keras.layers.convolutional import Convolution2D
from keras.optimizers import Adam
from keras.layers import InputLayer

def get_model(final_height, final_width, final_depth):
    
    image_shape = (final_height, final_width, final_depth)
    
    model = Sequential()
   
    model.add(Lambda(lambda x: x/127.5 - 1., input_shape=image_shape, output_shape=image_shape, name="input_images"))
    
    model.add(Convolution2D(24, 5, 5, subsample=(2, 2), border_mode="valid", activation='relu'))
    model.add(Convolution2D(36, 5, 5, subsample=(2, 2), border_mode="valid", activation='relu'))
    model.add(Convolution2D(48, 5, 5, subsample=(2, 2), border_mode="valid", activation='relu'))
    model.add(Convolution2D(64, 5, 5, subsample=(2, 2), border_mode="valid", activation='relu'))
    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(4, activation='softmax', name="output_labels"))
    
    optimizer = Adam(lr=0.001)
    model.compile(optimizer=optimizer, loss="sparse_categorical_crossentropy", metrics=['accuracy'])

    return model

# %% [markdown]
# ## 5. Train model

# %%
def generator(Xpath, y, batch_size):

    total_input = len(Xpath)
    
    while True:
        features, targets = [], []
        i = 0
        while len(features) < batch_size:
            index = randrange(0, total_input)
            path = Xpath[index]
            
            label = y[index]
            image = cv2.imread(path)
            image = augment_image(image, 2)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2YCR_CB)
           
            features.append(image)
            targets.append(label)
            
        yield (np.array(features), np.array(targets))

def getFeaturesTargets(Xpath, y):
    feats = []
    targets = []
    for path, label in zip(Xpath, y):
        image = cv2.imread(path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2YCR_CB)
        feats.append(image)
        targets.append(label)

    return np.array(feats), np.array(targets)

def plot_metrics(history):
    keys = history.history.keys()

    for k in keys:
        plt.clf()
        plt.plot(history.history[k])
        plt.title("model " + k)
        plt.ylabel(k)
        plt.xlabel('epoch')
        plt.show()
        
import json
from keras import backend as K
from tensorflow.contrib.session_bundle import exporter

def train_model(X_train, y_train, X_val, y_val):
    learning_rate = 0.001
    training_size = 3200
    batch_size = 160
    learning_rate = 0.001
    epochs = 30
    
    model = get_model(128, 128, 3)
    
    history =  model.fit_generator(
            generator(X_train, y_train, batch_size),
            samples_per_epoch = training_size,
            validation_data = getFeaturesTargets(X_val, y_val),
            nb_epoch = epochs
        )
 
    model.save_weights("model.h5")
    with open("model.json", "w+") as outfile:
        json.dump(model.to_json(), outfile)

    plot_metrics(history)

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_all, y_all, test_size=0.3, random_state=50)
train_model(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/30
#   24/3200 [..............................] - ETA: 5359s - loss: 1.3312 - acc: 0.3503
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-34612d584879> in <module>()
#      71
#      72 X_train, X_test, y_train, y_test = train_test_split(X_all, y_all, test_size=0.3, random_state=50)
# ---> 73 train_model(X_train, y_train, X_test, y_test)
#
# <ipython-input-27-34612d584879> in train_model(X_train, y_train, X_val, y_val)
#      59             samples_per_epoch = training_size,
#      60             validation_data = getFeaturesTargets(X_val, y_val),
# ---> 61             nb_epoch = epochs
#      62         )
#      63
#
# /home/sebastian/anaconda3/lib/python3.5/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      85                 warnings.warn('Update your `' + object_name +
#      86                               '` call to the Keras 2 API: ' + signature)
# ---> 87             return func(*args, **kwargs)
#      88         return wrapper
#      89     return legacy_support
#
# /home/sebastian/anaconda3/lib/python3.5/site-packages/keras/models.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_q_size, workers, pickle_safe, initial_epoch)
#    1095                                         workers=workers,
#    1096                                         pickle_safe=pickle_safe,
# -> 1097                                         initial_epoch=initial_epoch)
#    1098
#    1099     @interfaces.legacy_generator_methods_support
#
# /home/sebastian/anaconda3/lib/python3.5/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      85                 warnings.warn('Update your `' + object_name +
#      86                               '` call to the Keras 2 API: ' + signature)
# ---> 87             return func(*args, **kwargs)
#      88         return wrapper
#      89     return legacy_support
#
# /home/sebastian/anaconda3/lib/python3.5/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_q_size, workers, pickle_safe, initial_epoch)
#    1874                     outs = self.train_on_batch(x, y,
#    1875                                                sample_weight=sample_weight,
# -> 1876                                                class_weight=class_weight)
#    1877
#    1878                     if not isinstance(outs, list):
#
# /home/sebastian/anaconda3/lib/python3.5/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1618             ins = x + y + sample_weights
#    1619         self._make_train_function()
# -> 1620         outputs = self.train_function(ins)
#    1621         if len(outputs) == 1:
#    1622             return outputs[0]
#
# /home/sebastian/anaconda3/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2073         session = get_session()
#    2074         updated = session.run(self.outputs + [self.updates_op],
# -> 2075                               feed_dict=feed_dict)
#    2076         return updated[:len(self.outputs)]
#    2077
#
# /home/sebastian/anaconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/sebastian/anaconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /home/sebastian/anaconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/sebastian/anaconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /home/sebastian/anaconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ## 6. Export
# ### 6.1 Get tensorflow graph
#
# In order to be able to use the model in Android, it has to be a tensorflow model.

# %%
from tensorflow.contrib.session_bundle import exporter
from keras.models import model_from_json
from keras import backend as K
import tensorflow as tf
import json

def export_tensor():
    with open("model.json", 'r') as jfile:
        new_model = model_from_json(json.loads(jfile.read()))\

    new_model.compile("adam", "sparse_categorical_crossentropy")
    new_model.load_weights("model.h5")

    ####################################################################
    K.set_learning_phase(0)
    

    export_path = "./"
    export_version = 1

    sess = tf.Session()
    init_op = tf.global_variables_initializer()

    saver = tf.train.Saver(sharded=True)
    sess.run(init_op)
    model_exporter = exporter.Exporter(saver)
    signature = exporter.classification_signature(input_tensor=new_model.input,
                                                  scores_tensor=new_model.output)
   
    model_exporter.init(sess.graph.as_graph_def(),
                        default_graph_signature=signature)

    model_exporter.export(export_path, tf.constant(export_version), sess)
    
    tf.train.write_graph(sess.graph_def, ".", "seasonify.pb.txt")
    tf.train.write_graph(sess.graph_def, ".", "seasonify.pb", as_text=False)
    
    # input_images_input  input images
    # output_labels/Softmax output labels
    # [print(n.name) for n in tf.get_default_graph().as_graph_def().node]

export_tensor()
# Out:
# INFO:tensorflow:./00000001-tmp/export is not in all_model_checkpoint_paths. Manually adding it.
# input_images_input
# input_images/truediv/y
# input_images/truediv
# input_images/sub/y
# input_images/sub
# conv2d_1/random_uniform/shape
# conv2d_1/random_uniform/min
# conv2d_1/random_uniform/max
# conv2d_1/random_uniform/RandomUniform
# conv2d_1/random_uniform/sub
# conv2d_1/random_uniform/mul
# conv2d_1/random_uniform
# conv2d_1/kernel
# conv2d_1/kernel/Assign
# conv2d_1/kernel/read
# conv2d_1/Const
# conv2d_1/bias
# conv2d_1/bias/Assign
# conv2d_1/bias/read
# conv2d_1/convolution/Shape
# conv2d_1/convolution/dilation_rate
# conv2d_1/convolution
# conv2d_1/BiasAdd
# conv2d_1/Relu
# conv2d_2/random_uniform/shape
# conv2d_2/random_uniform/min
# conv2d_2/random_uniform/max
# conv2d_2/random_uniform/RandomUniform
# conv2d_2/random_uniform/sub
# conv2d_2/random_uniform/mul
# conv2d_2/random_uniform
# conv2d_2/kernel
# conv2d_2/kernel/Assign
# conv2d_2/kernel/read
# conv2d_2/Const
# conv2d_2/bias
# conv2d_2/bias/Assign
# conv2d_2/bias/read
# conv2d_2/convolution/Shape
# conv2d_2/convolution/dilation_rate
# conv2d_2/convolution
# conv2d_2/BiasAdd
# conv2d_2/Relu
# conv2d_3/random_uniform/shape
# conv2d_3/random_uniform/min
# conv2d_3/random_uniform/max
# conv2d_3/random_uniform/RandomUniform
# conv2d_3/random_uniform/sub
# conv2d_3/random_uniform/mul
# conv2d_3/random_uniform
# conv2d_3/kernel
# conv2d_3/kernel/Assign
# conv2d_3/kernel/read
# conv2d_3/Const
# conv2d_3/bias
# conv2d_3/bias/Assign
# conv2d_3/bias/read
# conv2d_3/convolution/Shape
# conv2d_3/convolution/dilation_rate
# conv2d_3/convolution
# conv2d_3/BiasAdd
# conv2d_3/Relu
# conv2d_4/random_uniform/shape
# conv2d_4/random_uniform/min
# conv2d_4/random_uniform/max
# conv2d_4/random_uniform/RandomUniform
# conv2d_4/random_uniform/sub
# conv2d_4/random_uniform/mul
# conv2d_4/random_uniform
# conv2d_4/kernel
# conv2d_4/kernel/Assign
# conv2d_4/kernel/read
# conv2d_4/Const
# conv2d_4/bias
# conv2d_4/bias/Assign
# conv2d_4/bias/read
# conv2d_4/convolution/Shape
# conv2d_4/convolution/dilation_rate
# conv2d_4/convolution
# conv2d_4/BiasAdd
# conv2d_4/Relu
# flatten_1/Shape
# flatten_1/strided_slice/stack
# flatten_1/strided_slice/stack_1
# flatten_1/strided_slice/stack_2
# flatten_1/strided_slice
# flatten_1/Const
# flatten_1/Prod
# flatten_1/stack/0
# flatten_1/stack
# flatten_1/Reshape
# dense_1/random_uniform/shape
# dense_1/random_uniform/min
# dense_1/random_uniform/max
# dense_1/random_uniform/RandomUniform
# dense_1/random_uniform/sub
# dense_1/random_uniform/mul
# dense_1/random_uniform
# dense_1/kernel
# dense_1/kernel/Assign
# dense_1/kernel/read
# dense_1/Const
# dense_1/bias
# dense_1/bias/Assign
# dense_1/bias/read
# dense_1/MatMul
# dense_1/BiasAdd
# dense_1/Relu
# dense_2/random_uniform/shape
# dense_2/random_uniform/min
# dense_2/random_uniform/max
# dense_2/random_uniform/RandomUniform
# dense_2/random_uniform/sub
# dense_2/random_uniform/mul
# dense_2/random_uniform
# dense_2/kernel
# dense_2/kernel/Assign
# dense_2/kernel/read
# dense_2/Const
# dense_2/bias
# dense_2/bias/Assign
# dense_2/bias/read
# dense_2/MatMul
# dense_2/BiasAdd
# dense_2/Relu
# dense_3/random_uniform/shape
# dense_3/random_uniform/min
# dense_3/random_uniform/max
# dense_3/random_uniform/RandomUniform
# dense_3/random_uniform/sub
# dense_3/random_uniform/mul
# dense_3/random_uniform
# dense_3/kernel
# dense_3/kernel/Assign
# dense_3/kernel/read
# dense_3/Const
# dense_3/bias
# dense_3/bias/Assign
# dense_3/bias/read
# dense_3/MatMul
# dense_3/BiasAdd
# dense_3/Relu
# output_labels/random_uniform/shape
# output_labels/random_uniform/min
# output_labels/random_uniform/max
# output_labels/random_uniform/RandomUniform
# output_labels/random_uniform/sub
# output_labels/random_uniform/mul
# output_labels/random_uniform
# output_labels/kernel
# output_labels/kernel/Assign
# output_labels/kernel/read
# output_labels/Const
# output_labels/bias
# output_labels/bias/Assign
# output_labels/bias/read
# output_labels/MatMul
# output_labels/BiasAdd
# output_labels/Softmax
# iterations/initial_value
# iterations
# iterations/Assign
# iterations/read
# lr/initial_value
# lr
# lr/Assign
# lr/read
# beta_1/initial_value
# beta_1
# beta_1/Assign
# beta_1/read
# beta_2/initial_value
# beta_2
# beta_2/Assign
# beta_2/read
# decay/initial_value
# decay
# decay/Assign
# decay/read
# output_labels_sample_weights
# output_labels_target
# Const
# sub/x
# sub
# clip_by_value/Minimum
# clip_by_value
# Log
# Reshape/shape
# Reshape
# Cast
# Reshape_1/shape
# Reshape_1
# SparseSoftmaxCrossEntropyWithLogits/Shape
# SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits
# Mean/reduction_indices
# Mean
# mul
# NotEqual/y
# NotEqual
# Cast_1
# Const_1
# Mean_1
# truediv
# Const_2
# Mean_2
# mul_1/x
# mul_1
# Max/reduction_indices
# Max
# ArgMax/dimension
# ArgMax
# Cast_2
# Equal
# Cast_3
# Const_3
# Mean_3
# input_images_input_1
# input_images_1/truediv/y
# input_images_1/truediv
# input_images_1/sub/y
# input_images_1/sub
# conv2d_5/random_uniform/shape
# conv2d_5/random_uniform/min
# conv2d_5/random_uniform/max
# conv2d_5/random_uniform/RandomUniform
# conv2d_5/random_uniform/sub
# conv2d_5/random_uniform/mul
# conv2d_5/random_uniform
# conv2d_5/kernel
# conv2d_5/kernel/Assign
# conv2d_5/kernel/read
# conv2d_5/Const
# conv2d_5/bias
# conv2d_5/bias/Assign
# conv2d_5/bias/read
# conv2d_5/convolution/Shape
# conv2d_5/convolution/dilation_rate
# conv2d_5/convolution
# conv2d_5/BiasAdd
# conv2d_5/Relu
# conv2d_6/random_uniform/shape
# conv2d_6/random_uniform/min
# conv2d_6/random_uniform/max
# conv2d_6/random_uniform/RandomUniform
# conv2d_6/random_uniform/sub
# conv2d_6/random_uniform/mul
# conv2d_6/random_uniform
# conv2d_6/kernel
# conv2d_6/kernel/Assign
# conv2d_6/kernel/read
# conv2d_6/Const
# conv2d_6/bias
# conv2d_6/bias/Assign
# conv2d_6/bias/read
# conv2d_6/convolution/Shape
# conv2d_6/convolution/dilation_rate
# conv2d_6/convolution
# conv2d_6/BiasAdd
# conv2d_6/Relu
# conv2d_7/random_uniform/shape
# conv2d_7/random_uniform/min
# conv2d_7/random_uniform/max
# conv2d_7/random_uniform/RandomUniform
# conv2d_7/random_uniform/sub
# conv2d_7/random_uniform/mul
# conv2d_7/random_uniform
# conv2d_7/kernel
# conv2d_7/kernel/Assign
# conv2d_7/kernel/read
# conv2d_7/Const
# conv2d_7/bias
# conv2d_7/bias/Assign
# conv2d_7/bias/read
# conv2d_7/convolution/Shape
# conv2d_7/convolution/dilation_rate
# conv2d_7/convolution
# conv2d_7/BiasAdd
# conv2d_7/Relu
# conv2d_8/random_uniform/shape
# conv2d_8/random_uniform/min
# conv2d_8/random_uniform/max
# conv2d_8/random_uniform/RandomUniform
# conv2d_8/random_uniform/sub
# conv2d_8/random_uniform/mul
# conv2d_8/random_uniform
# conv2d_8/kernel
# conv2d_8/kernel/Assign
# conv2d_8/kernel/read
# conv2d_8/Const
# conv2d_8/bias
# conv2d_8/bias/Assign
# conv2d_8/bias/read
# conv2d_8/convolution/Shape
# conv2d_8/convolution/dilation_rate
# conv2d_8/convolution
# conv2d_8/BiasAdd
# conv2d_8/Relu
# flatten_2/Shape
# flatten_2/strided_slice/stack
# flatten_2/strided_slice/stack_1
# flatten_2/strided_slice/stack_2
# flatten_2/strided_slice
# flatten_2/Const
# flatten_2/Prod
# flatten_2/stack/0
# flatten_2/stack
# flatten_2/Reshape
# dense_4/random_uniform/shape
# dense_4/random_uniform/min
# dense_4/random_uniform/max
# dense_4/random_uniform/RandomUniform
# dense_4/random_uniform/sub
# dense_4/random_uniform/mul
# dense_4/random_uniform
# dense_4/kernel
# dense_4/kernel/Assign
# dense_4/kernel/read
# dense_4/Const
# dense_4/bias
# dense_4/bias/Assign
# dense_4/bias/read
# dense_4/MatMul
# dense_4/BiasAdd
# dense_4/Relu
# dense_5/random_uniform/shape
# dense_5/random_uniform/min
# dense_5/random_uniform/max
# dense_5/random_uniform/RandomUniform
# dense_5/random_uniform/sub
# dense_5/random_uniform/mul
# dense_5/random_uniform
# dense_5/kernel
# dense_5/kernel/Assign
# dense_5/kernel/read
# dense_5/Const
# dense_5/bias
# dense_5/bias/Assign
# dense_5/bias/read
# dense_5/MatMul
# dense_5/BiasAdd
# dense_5/Relu
# dense_6/random_uniform/shape
# dense_6/random_uniform/min
# dense_6/random_uniform/max
# dense_6/random_uniform/RandomUniform
# dense_6/random_uniform/sub
# dense_6/random_uniform/mul
# dense_6/random_uniform
# dense_6/kernel
# dense_6/kernel/Assign
# dense_6/kernel/read
# dense_6/Const
# dense_6/bias
# dense_6/bias/Assign
# dense_6/bias/read
# dense_6/MatMul
# dense_6/BiasAdd
# dense_6/Relu
# output_labels_1/random_uniform/shape
# output_labels_1/random_uniform/min
# output_labels_1/random_uniform/max
# output_labels_1/random_uniform/RandomUniform
# output_labels_1/random_uniform/sub
# output_labels_1/random_uniform/mul
# output_labels_1/random_uniform
# output_labels_1/kernel
# output_labels_1/kernel/Assign
# output_labels_1/kernel/read
# output_labels_1/Const
# output_labels_1/bias
# output_labels_1/bias/Assign
# output_labels_1/bias/read
# output_labels_1/MatMul
# output_labels_1/BiasAdd
# output_labels_1/Softmax
# iterations_1/initial_value
# iterations_1
# iterations_1/Assign
# iterations_1/read
# lr_1/initial_value
# lr_1
# lr_1/Assign
# lr_1/read
# beta_1_1/initial_value
# beta_1_1
# beta_1_1/Assign
# beta_1_1/read
# beta_2_1/initial_value
# beta_2_1
# beta_2_1/Assign
# beta_2_1/read
# decay_1/initial_value
# decay_1
# decay_1/Assign
# decay_1/read
# output_labels_sample_weights_1
# output_labels_target_1
# Const_4
# sub_1/x
# sub_1
# clip_by_value_1/Minimum
# clip_by_value_1
# Log_1
# Reshape_2/shape
# Reshape_2
# Cast_4
# Reshape_3/shape
# Reshape_3
# SparseSoftmaxCrossEntropyWithLogits_1/Shape
# SparseSoftmaxCrossEntropyWithLogits_1/SparseSoftmaxCrossEntropyWithLogits
# Mean_4/reduction_indices
# lambda_4/truediv/y
# lambda_4/truediv
# lambda_4/sub/y
# lambda_4/sub
# convolution2d_10/random_uniform/shape
# convolution2d_10/random_uniform/min
# convolution2d_10/random_uniform/max
# convolution2d_10/random_uniform/RandomUniform
# convolution2d_10/random_uniform/sub
# convolution2d_10/random_uniform/mul
# convolution2d_10/random_uniform
# convolution2d_10/kernel
# convolution2d_10/kernel/Assign
# convolution2d_10/kernel/read
# convolution2d_10/Const
# convolution2d_10/bias
# convolution2d_10/bias/Assign
# convolution2d_10/bias/read
# convolution2d_10/convolution/Shape
# convolution2d_10/convolution/dilation_rate
# convolution2d_10/convolution
# convolution2d_10/BiasAdd
# convolution2d_10/Relu
# convolution2d_11/random_uniform/shape
# convolution2d_11/random_uniform/min
# convolution2d_11/random_uniform/max
# convolution2d_11/random_uniform/RandomUniform
# convolution2d_11/random_uniform/sub
# convolution2d_11/random_uniform/mul
# convolution2d_11/random_uniform
# convolution2d_11/kernel
# convolution2d_11/kernel/Assign
# convolution2d_11/kernel/read
# convolution2d_11/Const
# convolution2d_11/bias
# convolution2d_11/bias/Assign
# convolution2d_11/bias/read
# convolution2d_11/convolution/Shape
# convolution2d_11/convolution/dilation_rate
# convolution2d_11/convolution
# convolution2d_11/BiasAdd
# convolution2d_11/Relu
# convolution2d_12/random_uniform/shape
# convolution2d_12/random_uniform/min
# convolution2d_12/random_uniform/max
# convolution2d_12/random_uniform/RandomUniform
# convolution2d_12/random_uniform/sub
# convolution2d_12/random_uniform/mul
# convolution2d_12/random_uniform
# convolution2d_12/kernel
# convolution2d_12/kernel/Assign
# convolution2d_12/kernel/read
# convolution2d_12/Const
# convolution2d_12/bias
# convolution2d_12/bias/Assign
# convolution2d_12/bias/read
# convolution2d_12/convolution/Shape
# convolution2d_12/convolution/dilation_rate
# convolution2d_12/convolution
# convolution2d_12/BiasAdd
# convolution2d_12/Relu
# convolution2d_13/random_uniform/shape
# convolution2d_13/random_uniform/min
# convolution2d_13/random_uniform/max
# convolution2d_13/random_uniform/RandomUniform
# convolution2d_13/random_uniform/sub
# convolution2d_13/random_uniform/mul
# convolution2d_13/random_uniform
# convolution2d_13/kernel
# convolution2d_13/kernel/Assign
# convolution2d_13/kernel/read
# convolution2d_13/Const
# convolution2d_13/bias
# convolution2d_13/bias/Assign
# convolution2d_13/bias/read
# convolution2d_13/convolution/Shape
# convolution2d_13/convolution/dilation_rate
# convolution2d_13/convolution
# convolution2d_13/BiasAdd
# convolution2d_13/Relu
# flatten_2_1/Shape
# flatten_2_1/strided_slice/stack
# flatten_2_1/strided_slice/stack_1
# flatten_2_1/strided_slice/stack_2
# flatten_2_1/strided_slice
# flatten_2_1/Const
# flatten_2_1/Prod
# flatten_2_1/stack/0
# flatten_2_1/stack
# flatten_2_1/Reshape
# dense_5_1/random_uniform/shape
# dense_5_1/random_uniform/min
# dense_5_1/random_uniform/max
# dense_5_1/random_uniform/RandomUniform
# dense_5_1/random_uniform/sub
# dense_5_1/random_uniform/mul
# dense_5_1/random_uniform
# dense_5_1/kernel
# dense_5_1/kernel/Assign
# dense_5_1/kernel/read
# dense_5_1/Const
# dense_5_1/bias
# dense_5_1/bias/Assign
# dense_5_1/bias/read
# dense_5_1/MatMul
# dense_5_1/BiasAdd
# dense_5_1/Relu
# dense_6_1/random_uniform/shape
# dense_6_1/random_uniform/min
# dense_6_1/random_uniform/max
# dense_6_1/random_uniform/RandomUniform
# dense_6_1/random_uniform/sub
# dense_6_1/random_uniform/mul
# dense_6_1/random_uniform
# dense_6_1/kernel
# dense_6_1/kernel/Assign
# dense_6_1/kernel/read
# dense_6_1/Const
# dense_6_1/bias
# dense_6_1/bias/Assign
# dense_6_1/bias/read
# dense_6_1/MatMul
# dense_6_1/BiasAdd
# dense_6_1/Relu
# dense_7/random_uniform/shape
# dense_7/random_uniform/min
# dense_7/random_uniform/max
# dense_7/random_uniform/RandomUniform
# dense_7/random_uniform/sub
# dense_7/random_uniform/mul
# dense_7/random_uniform
# dense_7/kernel
# dense_7/kernel/Assign
# dense_7/kernel/read
# dense_7/Const
# dense_7/bias
# dense_7/bias/Assign
# dense_7/bias/read
# dense_7/MatMul
# dense_7/BiasAdd
# dense_7/Relu
# dense_8/random_uniform/shape
# dense_8/random_uniform/min
# dense_8/random_uniform/max
# dense_8/random_uniform/RandomUniform
# dense_8/random_uniform/sub
# dense_8/random_uniform/mul
# dense_8/random_uniform
# dense_8/kernel
# dense_8/kernel/Assign
# dense_8/kernel/read
# dense_8/Const
# dense_8/bias
# dense_8/bias/Assign
# dense_8/bias/read
# dense_8/MatMul
# dense_8/BiasAdd
# dense_8/Softmax
# iterations_2/initial_value
# iterations_2
# iterations_2/Assign
# iterations_2/read
# lr_2/initial_value
# lr_2
# lr_2/Assign
# lr_2/read
# beta_1_2/initial_value
# beta_1_2
# beta_1_2/Assign
# beta_1_2/read
# beta_2_2/initial_value
# beta_2_2
# beta_2_2/Assign
# beta_2_2/read
# decay_2/initial_value
# decay_2
# decay_2/Assign
# decay_2/read
# dense_8_sample_weights
# dense_8_target
# Const_74
# sub_52/x
# sub_52
# clip_by_value_19/Minimum
# clip_by_value_19
# Log_2
# Reshape_4/shape
# Reshape_4
# Cast_8
# Reshape_5/shape
# Reshape_5
# SparseSoftmaxCrossEntropyWithLogits_2/Shape
# SparseSoftmaxCrossEntropyWithLogits_2/SparseSoftmaxCrossEntropyWithLogits
# Mean_8/reduction_indices
# Mean_8
# mul_85
# NotEqual_2/y
# NotEqual_2
# Cast_9
# Const_75
# Mean_9
# truediv_19
# Const_76
# Mean_10
# mul_86/x
# mul_86
# Placeholder
# Assign_48
# Placeholder_1
# Assign_49
# Placeholder_2
# Assign_50
# Placeholder_3
# Assign_51
# Placeholder_4
# Assign_52
# Placeholder_5
# Assign_53
# Placeholder_6
# Assign_54
# Placeholder_7
# Assign_55
# Placeholder_8
# Assign_56
# Placeholder_9
# Assign_57
# Placeholder_10
# Assign_58
# Placeholder_11
# Assign_59
# Placeholder_12
# Assign_60
# Placeholder_13
# Assign_61
# Placeholder_14
# Assign_62
# Placeholder_15
# Assign_63
# init_1
# flatten_2_2/stack/0
# flatten_2_2/stack
# flatten_2_2/Reshape
# dense_5_2/random_uniform/shape
# dense_5_2/random_uniform/min
# dense_5_2/random_uniform/max
# dense_5_2/random_uniform/RandomUniform
# dense_5_2/random_uniform/sub
# dense_5_2/random_uniform/mul
# dense_5_2/random_uniform
# dense_5_2/kernel
# dense_5_2/kernel/Assign
# dense_5_2/kernel/read
# dense_5_2/Const
# dense_5_2/bias
# dense_5_2/bias/Assign
# dense_5_2/bias/read
# dense_5_2/MatMul
# dense_5_2/BiasAdd
# dense_5_2/Relu
# dense_6_2/random_uniform/shape
# dense_6_2/random_uniform/min
# dense_6_2/random_uniform/max
# dense_6_2/random_uniform/RandomUniform
# dense_6_2/random_uniform/sub
# dense_6_2/random_uniform/mul
# dense_6_2/random_uniform
# dense_6_2/kernel
# dense_6_2/kernel/Assign
# dense_6_2/kernel/read
# dense_6_2/Const
# dense_6_2/bias
# dense_6_2/bias/Assign
# dense_6_2/bias/read
# dense_6_2/MatMul
# dense_6_2/BiasAdd
# dense_6_2/Relu
# dense_7_1/random_uniform/shape
# dense_7_1/random_uniform/min
# dense_7_1/random_uniform/max
# dense_7_1/random_uniform/RandomUniform
# dense_7_1/random_uniform/sub
# dense_7_1/random_uniform/mul
# dense_7_1/random_uniform
# dense_7_1/kernel
# dense_7_1/kernel/Assign
# dense_7_1/kernel/read
# dense_7_1/Const
# dense_7_1/bias
# dense_7_1/bias/Assign
# dense_7_1/bias/read
# dense_7_1/MatMul
# dense_7_1/BiasAdd
# dense_7_1/Relu
# dense_8_1/random_uniform/shape
# dense_8_1/random_uniform/min
# dense_8_1/random_uniform/max
# dense_8_1/random_uniform/RandomUniform
# dense_8_1/random_uniform/sub
# dense_8_1/random_uniform/mul
# dense_8_1/random_uniform
# dense_8_1/kernel
# dense_8_1/kernel/Assign
# dense_8_1/kernel/read
# dense_8_1/Const
# dense_8_1/bias
# dense_8_1/bias/Assign
# dense_8_1/bias/read
# dense_8_1/MatMul
# dense_8_1/BiasAdd
# dense_8_1/Softmax
# iterations_3/initial_value
# iterations_3
# iterations_3/Assign
# iterations_3/read
# lr_3/initial_value
# lr_3
# lr_3/Assign
# lr_3/read
# beta_1_3/initial_value
# beta_1_3
# beta_1_3/Assign
# beta_1_3/read
# beta_2_3/initial_value
# beta_2_3
# beta_2_3/Assign
# beta_2_3/read
# decay_3/initial_value
# decay_3
# decay_3/Assign
# decay_3/read
# dense_8_sample_weights_1
# dense_8_target_1
# Const_77
# sub_53/x
# sub_53
# clip_by_value_20/Minimum
# clip_by_value_20
# Log_3
# Reshape_6/shape
# Reshape_6
# Cast_10
# Reshape_7/shape
# Reshape_7
# SparseSoftmaxCrossEntropyWithLogits_3/Shape
# SparseSoftmaxCrossEntropyWithLogits_3/SparseSoftmaxCrossEntropyWithLogits
# Mean_11/reduction_indices
# Mean_11
# mul_87
# NotEqual_3/y
# NotEqual_3
# Cast_11
# Const_78
# Mean_12
# truediv_20
# Const_79
# Mean_13
# mul_88/x
# mul_88
# Placeholder_16
# convolution2d_11_2/random_uniform/min
# convolution2d_11_2/random_uniform/max
# convolution2d_11_2/random_uniform/RandomUniform
# convolution2d_11_2/random_uniform/sub
# convolution2d_11_2/random_uniform/mul
# convolution2d_11_2/random_uniform
# convolution2d_11_2/kernel
# convolution2d_11_2/kernel/Assign
# convolution2d_11_2/kernel/read
# convolution2d_11_2/Const
# convolution2d_11_2/bias
# convolution2d_11_2/bias/Assign
# convolution2d_11_2/bias/read
# convolution2d_11_2/convolution/Shape
# convolution2d_11_2/convolution/dilation_rate
# convolution2d_11_2/convolution
# convolution2d_11_2/BiasAdd
# convolution2d_11_2/Relu
# convolution2d_12_2/random_uniform/shape
# convolution2d_12_2/random_uniform/min
# convolution2d_12_2/random_uniform/max
# convolution2d_12_2/random_uniform/RandomUniform
# convolution2d_12_2/random_uniform/sub
# convolution2d_12_2/random_uniform/mul
# convolution2d_12_2/random_uniform
# convolution2d_12_2/kernel
# convolution2d_12_2/kernel/Assign
# convolution2d_12_2/kernel/read
# convolution2d_12_2/Const
# convolution2d_12_2/bias
# convolution2d_12_2/bias/Assign
# convolution2d_12_2/bias/read
# convolution2d_12_2/convolution/Shape
# convolution2d_12_2/convolution/dilation_rate
# convolution2d_12_2/convolution
# convolution2d_12_2/BiasAdd
# convolution2d_12_2/Relu
# convolution2d_13_2/random_uniform/shape
# convolution2d_13_2/random_uniform/min
# convolution2d_13_2/random_uniform/max
# convolution2d_13_2/random_uniform/RandomUniform
# convolution2d_13_2/random_uniform/sub
# convolution2d_13_2/random_uniform/mul
# convolution2d_13_2/random_uniform
# convolution2d_13_2/kernel
# convolution2d_13_2/kernel/Assign
# convolution2d_13_2/kernel/read
# convolution2d_13_2/Const
# convolution2d_13_2/bias
# convolution2d_13_2/bias/Assign
# convolution2d_13_2/bias/read
# convolution2d_13_2/convolution/Shape
# convolution2d_13_2/convolution/dilation_rate
# convolution2d_13_2/convolution
# convolution2d_13_2/BiasAdd
# convolution2d_13_2/Relu
# flatten_2_3/Shape
# flatten_2_3/strided_slice/stack
# flatten_2_3/strided_slice/stack_1
# flatten_2_3/strided_slice/stack_2
# flatten_2_3/strided_slice
# flatten_2_3/Const
# flatten_2_3/Prod
# flatten_2_3/stack/0
# flatten_2_3/stack
# flatten_2_3/Reshape
# dense_5_3/random_uniform/shape
# dense_5_3/random_uniform/min
# dense_5_3/random_uniform/max
# dense_5_3/random_uniform/RandomUniform
# dense_5_3/random_uniform/sub
# dense_5_3/random_uniform/mul
# dense_5_3/random_uniform
# dense_5_3/kernel
# dense_5_3/kernel/Assign
# dense_5_3/kernel/read
# dense_5_3/Const
# dense_5_3/bias
# dense_5_3/bias/Assign
# dense_5_3/bias/read
# dense_5_3/MatMul
# dense_5_3/BiasAdd
# dense_5_3/Relu
# dense_6_3/random_uniform/shape
# dense_6_3/random_uniform/min
# dense_6_3/random_uniform/max
# dense_6_3/random_uniform/RandomUniform
# dense_6_3/random_uniform/sub
# dense_6_3/random_uniform/mul
# dense_6_3/random_uniform
# dense_6_3/kernel
# dense_6_3/kernel/Assign
# dense_6_3/kernel/read
# dense_6_3/Const
# dense_6_3/bias
# dense_6_3/bias/Assign
# dense_6_3/bias/read
# dense_6_3/MatMul
# dense_6_3/BiasAdd
# dense_6_3/Relu
# dense_7_2/random_uniform/shape
# dense_7_2/random_uniform/min
# dense_7_2/random_uniform/max
# dense_7_2/random_uniform/RandomUniform
# dense_7_2/random_uniform/sub
# dense_7_2/random_uniform/mul
# dense_7_2/random_uniform
# dense_7_2/kernel
# dense_7_2/kernel/Assign
# dense_7_2/kernel/read
# dense_7_2/Const
# dense_7_2/bias
# dense_7_2/bias/Assign
# dense_7_2/bias/read
# dense_7_2/MatMul
# dense_7_2/BiasAdd
# dense_7_2/Relu
# dense_8_2/random_uniform/shape
# dense_8_2/random_uniform/min
# dense_8_2/random_uniform/max
# dense_8_2/random_uniform/RandomUniform
# dense_8_2/random_uniform/sub
# dense_8_2/random_uniform/mul
# dense_8_2/random_uniform
# dense_8_2/kernel
# dense_8_2/kernel/Assign
# dense_8_2/kernel/read
# dense_8_2/Const
# dense_8_2/bias
# dense_8_2/bias/Assign
# dense_8_2/bias/read
# dense_8_2/MatMul
# dense_8_2/BiasAdd
# dense_8_2/Softmax
# iterations_4/initial_value
# iterations_4
# iterations_4/Assign
# iterations_4/read
# lr_4/initial_value
# lr_4
# ...
# decay_4
# decay_4/Assign
# decay_4/read
# dense_8_sample_weights_2
# dense_8_target_2
# Const_81
# sub_54/x
# sub_54
# clip_by_value_21/Minimum
# clip_by_value_21
# Log_4
# Reshape_8/shape
# Reshape_8
# Cast_12
# Reshape_9/shape
# Reshape_9
# SparseSoftmaxCrossEntropyWithLogits_4/Shape
# SparseSoftmaxCrossEntropyWithLogits_4/SparseSoftmaxCrossEntropyWithLogits
# Mean_14/reduction_indices
# Mean_14
# mul_89
# NotEqual_4/y
# NotEqual_4
# Cast_13
# Const_82
# Mean_15
# truediv_21
# Const_83
# Mean_16
# mul_90/x
# mul_90
# Placeholder_32
# Assign_80
# Placeholder_33
# Assign_81
# Placeholder_34
# Assign_82
# Placeholder_35
# Assign_83
# Placeholder_36
# Assign_84
# Placeholder_37
# Assign_85
# Placeholder_38
# Assign_86
# Placeholder_39
# Assign_87
# Placeholder_40
# Assign_88
# Placeholder_41
# Assign_89
# Placeholder_42
# Assign_90
# Placeholder_43
# Assign_91
# Placeholder_44
# Assign_92
# Placeholder_45
# Assign_93
# Placeholder_46
# Assign_94
# Placeholder_47
# Assign_95
# init_4
# init_5
# save_1/Const
# save_1/StringJoin/inputs_1
# save_1/StringJoin
# save_1/num_shards
# save_1/ShardedFilename/shard
# save_1/ShardedFilename
# save_1/SaveV2/tensor_names
# save_1/SaveV2/shape_and_slices
# save_1/SaveV2
# save_1/control_dependency
# save_1/MergeV2Checkpoints/checkpoint_prefixes
# save_1/MergeV2Checkpoints
# save_1/Identity
# save_1/RestoreV2/tensor_names
# save_1/RestoreV2/shape_and_slices
# save_1/RestoreV2
# save_1/Assign
# save_1/RestoreV2_1/tensor_names
# save_1/RestoreV2_1/shape_and_slices
# save_1/Assign_116
# save_1/RestoreV2_117/tensor_names
# save_1/RestoreV2_117/shape_and_slices
# save_1/RestoreV2_117
# save_1/Assign_117
# save_1/RestoreV2_118/tensor_names
# save_1/RestoreV2_118/shape_and_slices
# save_1/RestoreV2_118
# save_1/Assign_118
# save_1/RestoreV2_119/tensor_names
# save_1/RestoreV2_119/shape_and_slices
# save_1/RestoreV2_119
# save_1/Assign_119
# save_1/RestoreV2_120/tensor_names
# save_1/RestoreV2_120/shape_and_slices
# save_1/RestoreV2_120
# save_1/Assign_120
# save_1/RestoreV2_121/tensor_names
# save_1/RestoreV2_121/shape_and_slices
# save_1/RestoreV2_121
# save_1/Assign_121
# save_1/RestoreV2_122/tensor_names
# save_1/RestoreV2_122/shape_and_slices
# save_1/RestoreV2_122
# save_1/Assign_122
# save_1/RestoreV2_123/tensor_names
# save_1/RestoreV2_123/shape_and_slices
# save_1/RestoreV2_123
# save_1/Assign_123
# save_1/RestoreV2_124/tensor_names
# save_1/RestoreV2_124/shape_and_slices
# save_1/RestoreV2_124
# save_1/Assign_124
# save_1/RestoreV2_125/tensor_names
# save_1/RestoreV2_125/shape_and_slices
# save_1/RestoreV2_125
# save_1/Assign_125
# save_1/RestoreV2_126/tensor_names
# save_1/RestoreV2_126/shape_and_slices
# save_1/RestoreV2_126
# save_1/Assign_126
# save_1/RestoreV2_127/tensor_names
# save_1/RestoreV2_127/shape_and_slices
# save_1/RestoreV2_127
# save_1/Assign_127
# save_1/RestoreV2_128/tensor_names
# save_1/RestoreV2_128/shape_and_slices
# save_1/RestoreV2_128
# save_1/Assign_128
# save_1/RestoreV2_129/tensor_names
# save_1/RestoreV2_129/shape_and_slices
# save_1/RestoreV2_129
# save_1/Assign_129
# save_1/RestoreV2_130/tensor_names
# save_1/RestoreV2_130/shape_and_slices
# save_1/RestoreV2_130
# save_1/Assign_130
# save_1/RestoreV2_131/tensor_names
# save_1/RestoreV2_131/shape_and_slices
# save_1/RestoreV2_131
# save_1/Assign_131
# save_1/RestoreV2_132/tensor_names
# save_1/RestoreV2_132/shape_and_slices
# save_1/RestoreV2_132
# save_1/Assign_132
# save_1/RestoreV2_133/tensor_names
# save_1/RestoreV2_133/shape_and_slices
# save_1/RestoreV2_133
# save_1/Assign_133
# save_1/RestoreV2_134/tensor_names
# save_1/RestoreV2_134/shape_and_slices
# save_1/RestoreV2_134
# save_1/Assign_134
# save_1/RestoreV2_135/tensor_names
# save_1/RestoreV2_135/shape_and_slices
# save_1/RestoreV2_135
# save_1/Assign_135
# save_1/RestoreV2_136/tensor_names
# save_1/RestoreV2_136/shape_and_slices
# save_1/RestoreV2_136
# save_1/Assign_136
# save_1/restore_shard
# save_1/restore_all
# Const_84

# %% [markdown]
# ### 6.2 Freeze graph

# %%
import tensorflow as tf
from tensorflow.python.framework import graph_util

def freeze_graph():
    # We retrieve our checkpoint fullpath
    checkpoint = tf.train.get_checkpoint_state(".")
    input_checkpoint = checkpoint.model_checkpoint_path
    
    # We precise the file fullname of our freezed graph
    absolute_model_folder = "/".join(input_checkpoint.split('/')[:-1])
    output_graph = absolute_model_folder + "/frozen_model.pb"

    # Before exporting our graph, we need to precise what is our output node
    # This is how TF decides what part of the Graph he has to keep and what part it can dump
    # NOTE: this variable is plural, because you can have multiple output nodes
    output_node_names = "output_labels/Softmax"

    # We clear devices to allow TensorFlow to control on which device it will load operations
    clear_devices = True
    
    # We import the meta graph and retrieve a Saver
    saver = tf.train.import_meta_graph(input_checkpoint + '.meta', clear_devices=clear_devices)

    # We retrieve the protobuf graph definition
    graph = tf.get_default_graph()
    input_graph_def = graph.as_graph_def()

    # We start a session and restore the graph weights
    with tf.Session() as sess:
        saver.restore(sess, input_checkpoint)

        # We use a built-in TF helper to export variables to constants
        output_graph_def = graph_util.convert_variables_to_constants(
            sess, # The session is used to retrieve the weights
            input_graph_def, # The graph_def is used to retrieve the nodes 
            output_node_names.split(",") # The output node names are used to select the usefull nodes
        ) 

        # Finally we serialize and dump the output graph to the filesystem
        with tf.gfile.GFile(output_graph, "wb") as f:
            f.write(output_graph_def.SerializeToString())

        print("%d ops in the final graph." % len(output_graph_def.node))

freeze_graph()
# Out:
# INFO:tensorflow:Froze 16 variables.
# Converted 16 variables to const ops.
# 71 ops in the final graph.

# %% [markdown]
# ## 7. Predict

# %%
def load_data_unseen():
    
    autumn_path = "./testing/autumn"
    spring_path = "./testing/spring"
    summer_path = "./testing/summer"
    winter_path = "./testing/winter"

    X, y = [], []

    # autumn = 0
    # spring = 1
    # summer = 2
    # winter = 3
    for i, season_path in enumerate([autumn_path, spring_path, summer_path, winter_path]):
        for fname in glob.glob(season_path + "/*"): # regex for front images
            X.append(fname)
            y.append(i)
        
    return np.array(X), np.array(y)

# X_testing, y_testing = load_data_unseen()
X_testing, y_testing = load_data("color_feret")

def preprocess_image(x):
    x = cv2.resize(x, (128,128))
    x = cv2.cvtColor(x, cv2.COLOR_BGR2YCR_CB)
    
    return x

def make_prediction(clf, image):
#     pred = clf.predict(image.reshape((1, -1)), batch_size=1)
    pred = clf.predict(np.array([image]), batch_size=1)
    class_result = np.argmax(pred, axis=-1)
    
    return class_result[0]

def get_images(X_data, y_data, clazz):
    samples = []
    
    for index, x in enumerate(X_data):
        y = y_data[index]
        
        if y == clazz:
            samples.append(X_data[index])
            
    return np.array(samples)

from keras.models import model_from_json

def plot_random_predictions():
    with open("model.json", 'r') as jfile:
        model = model_from_json(json.loads(jfile.read()))\

    model.compile("adam", "mse")
    model.load_weights("model.h5")
    
    classes = ["Autumn", "Spring", "Summer", "Winter"]
    for i, clazz in enumerate(classes):
#         paths = get_images(X_testing, y_testing, i)
        paths = get_random_images(X_testing, y_testing, 12, i)
        images = []
        titles = []
        colors = []
        for path in paths:
            image = cv2.imread(path)
            image_pre = preprocess_image(image)
            prediction = make_prediction(model, image_pre)
            title = "R: {} \n\nP: {}".format(clazz, classes[prediction])
            
            if clazz == classes[prediction]:
                color = "red"
            else:
                color = "black"
            
            images.append(image)
            titles.append(title)
            colors.append(color)
        
        plot_images(images, titles, colors)

plot_random_predictions()
